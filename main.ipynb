# %%
from ipynb.fs.full.utils import *

# %%
path = 'x.png'

# %%
result = find_result(path)
cv2.imshow('result',result)
cv2.waitKey(0)
# Out:
# ...
# 1/1 [==============================] - 0s 17ms/step
# -1
